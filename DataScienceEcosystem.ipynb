# %% [markdown]
# # Data Science Tools and Ecosystem

# %% [markdown]
# In this notebook, we summarize some of the popular tools and technologies used by data scientists.

# %% [markdown]
# ### Data Science Languages
# Some of the most popular languages used by data scientists are:
# 1. Python
# 2. R
# 3. SQL
# 4. Julia
# 5. Scala

# %% [markdown]
# ### Data Science Libraries
# Commonly used libraries for data science include:
# 1. Pandas
# 2. NumPy
# 3. Matplotlib
# 4. Scikit-learn
# 5. TensorFlow
# 6. PyTorch

# %% [markdown]
# | Data Science Tools | Category         |
# |--------------------|------------------|
# | Jupyter Notebook   | IDE/Notebook     |
# | RStudio            | IDE/Notebook     |
# | TensorFlow         | Machine Learning |
# | Apache Spark       | Big Data         |
# | Apache Hadoop      | Big Data         |

# %% [markdown]
# ### Examples of Arithmetic Expressions
# Below are some simple arithmetic operations using Python.

# %%
# This code multiplies and adds numbers
(3 * 4) + 5

# %%
# Convert 200 minutes into hours
minutes = 200
hours = minutes / 60
hours

# %% [markdown]
# ### Objectives
# After completing this notebook, you will be able to:
# - List popular languages for Data Science
# - Identify commonly used libraries
# - Demonstrate basic arithmetic expressions
# - Convert minutes to hours using Python
# - Share your work through GitHub

# %% [markdown]
# **Author:** Mohit Dahiya

# %% [markdown]
# > **Sharing reminder:** Download this notebook (`File → Save As → Download .ipynb`) and upload it to a public GitHub repository.
# > Paste the GitHub URL in your course submission for Exercise 12.
